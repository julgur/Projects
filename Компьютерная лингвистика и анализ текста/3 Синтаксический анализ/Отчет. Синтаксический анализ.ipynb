# %% [markdown]
# # HW3: Синтаксический анализ, коллокации

# %%
import pandas as pd
import numpy as np

import pymorphy2
import xml.etree.ElementTree as etree
import opencorpora
from pymystem3 import Mystem

morph = pymorphy2.MorphAnalyzer()

# %% [markdown]
# Проверим работу pymorphy2

# %%
morph.parse('матери')
# Out:
# [Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='матерь', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 1),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='мать', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 1),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,datv'), normal_form='матерь', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 2),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,loct'), normal_form='матерь', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 5),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn plur,nomn'), normal_form='матерь', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 6),)),
#  Parse(word='матери', tag=OpencorporaTag('VERB,impf,tran sing,impr,excl'), normal_form='материть', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 463, 11),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,datv'), normal_form='мать', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 2),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,loct'), normal_form='мать', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 5),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn plur,nomn'), normal_form='мать', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 6),))]

# %%
def read_txt(file):
    ''' 
    Функция считывает текст из файла .txt, разбивает на токены, проводит морфологический анализ каждого токена, возвращает 
    текст и список токенов в формате pymorphy2. 
    '''
    text = open(file, 'r').read()
    l = Mystem().analyze(text)
    tokens = []
    for t in l:
        try:
            tokens.append((t['text'],t['analysis']))
        except KeyError:
            pass    
    words = [word[0] for word in tokens]
    morph_w = [morph.parse(w)[0] for w in words]
    return text, morph_w

# %%
def find_AN(tokens_parsed):
    '''
     принимает список токенов в формате pymorphy, возвращает список словосочетаний формата прилагательное+существительное 
     и существительное+прилагательное. Словосочетание считается согласованным, если у прилагательного и существительного 
     совпадают род, число и падеж. Числительные и местоименные прилагательные так же учитываются.
    '''
    AN_list = []
    for i in range(len(tokens_parsed)):
        if tokens_parsed[i].tag.POS == 'ADJF':
            for j in range(i+1,i+4):
                if (tokens_parsed[j].tag.POS == 'NOUN' and 
                    tokens_parsed[i].tag.gender == tokens_parsed[j].tag.gender and 
                    tokens_parsed[i].tag.number == tokens_parsed[j].tag.number and
                    tokens_parsed[i].tag.case == tokens_parsed[j].tag.case):
                    AN_list.append(tokens_parsed[i].word+' '+tokens_parsed[j].word)
            for j in range(i-1,i):
                if (tokens_parsed[j].tag.POS == 'NOUN' and 
                    tokens_parsed[i].tag.gender == tokens_parsed[j].tag.gender and 
                    tokens_parsed[i].tag.number == tokens_parsed[j].tag.number and
                    tokens_parsed[i].tag.case == tokens_parsed[j].tag.case):
                    AN_list.append(tokens_parsed[j].word+' '+tokens_parsed[i].word)

    return AN_list

# %%
def find_VN_tran(tokens):
    '''
    принимает список токенов в формате pymorphy, возвращает список словосочетаний формата 
    переходный глагол+NP(вида прилагательные+существительное в винительном падеже)
    '''
    AN_groups = dict()
    for i in range(len(tokens)):
        if tokens[i].tag.POS == 'ADJF':
            for j in range(i+1,i+4):
                if (tokens[j].tag.POS == 'NOUN' and 
                    tokens[i].tag.gender == tokens[j].tag.gender and 
                    tokens[i].tag.number == tokens[j].tag.number and
                    tokens[i].tag.case == tokens[j].tag.case):
                        AN_groups[j]=tokens[i].word+' '+AN_groups.get(j,'')
                    
#            for j in range(i-1,i):
#                if (tokens_parsed[j].tag.POS == 'NOUN' and 
#                    tokens_parsed[i].tag.gender == tokens_parsed[j].tag.gender and 
#                    tokens_parsed[i].tag.number == tokens_parsed[j].tag.number and
#                    tokens_parsed[i].tag.case == tokens_parsed[j].tag.case):
#                    AN_groups[j]=AN_groups[j].get('')+' '+tokens_parsed[i].word

#                    AN_list.append(tokens_parsed[j].word+' '+tokens_parsed[i].word)
    VN_list = []
    for i in range(len(tokens)):
        if tokens[i].tag.POS == 'VERB' and tokens[i].tag.transitivity == 'tran':
            for j in range(i+1,i+3):
                if (tokens[j].tag.POS == 'NOUN' and tokens[j].tag.case == 'accs'):
                    VN_list.append(tokens[i].word+' '+AN_groups.get(j,'')+tokens[j].word)
    return VN_list

# %%
def find_AV(tokens):
    VN_list = []
    VN_groups = {}
    for i in range(len(tokens)):
        if tokens[i].tag.POS == 'ADVB':
            for j in range(i+1,i+3):
                if tokens[j].tag.POS == 'VERB':
                    VN_list.append(tokens[i].word+' '+VN_groups.get(j,'')+tokens[j].word)
                    VN_groups[j]=tokens[i].word+' '+VN_groups.get(j,'')
            for j in range(i-2,i):
                if tokens[j].tag.POS == 'VERB':
                    VN_list.append(tokens[j].word+' '+VN_groups.get(j,'')+tokens[i].word)
                    VN_groups[j]=tokens[i].word+' '+VN_groups.get(j,'')


    return VN_list

# %% [markdown]
# ## Репортаж Медузы

# %%
text, toks = read_txt('text.txt')

# %%
print(text)
# Out:
# На выборах 9 сентября 2018 года Якутск стал единственной региональной столицей, где мэром был избран представитель оппозиции. 48-летняя Сардана Авксентьева обошла единоросса Александра Саввинова, поддержанного губернатором, и стала первой женщиной-градоначальником в истории города. После избрания Авксентьева развернула бурную деятельность, направленную на исполнение «народного заказа»: принялась сокращать расходы на городской аппарат; увольнять сомнительных чиновников и подрядчиков; распродавать записанные на мэрию дорогие машины. В результате Авксентьева стала общероссийской знаменитостью — а успехами якутской мэрии в интернете даже заинтересовались в администрации президента. Спецкор «Медузы» Таисия Бекбулатова отправилась в Якутск, чтобы понять, как Авксентьевой удалось победить и какое будущее ее ждет.
#
#
# Out:
# ['где был',
#  'уже участвовал',
#  'быстро повысят',
#  'действительно возглавил',
#  'было по-другому',
#  'сейчас говорит',
#  'целенаправленно шёл',
#  'снова отказался',
#  'уже сидел',
#  'прямо бежит',
#  'одновременно снял',
#  'отзываем одновременно',
#  'была уже',
#  'говорит естественно',
#  'прекрасно понимал',
#  'будет выше',
#  'далее рассказывает',
#  'естественно был',
#  'хорошо запомнили',
#  'появились вынужденно',
#  'уже имела',
#  'вышла замуж',
#  'где был',
#  'уже участвовал',
#  'быстро повысят',
#  'действительно возглавил',
#  'было по-другому',
#  'сейчас говорит',
#  'целенаправленно шёл',
#  'снова отказался',
#  'уже сидел',
#  'прямо бежит',
#  'одновременно снял',
#  'отзываем одновременно',
#  'была уже',
#  'говорит естественно',
#  'прекрасно понимал',
#  'будет выше',
#  'далее рассказывает',
#  'естественно был',
#  'хорошо запомнили',
#  'появились вынужденно',
#  'уже имела',
#  'вышла замуж',
#  'тоже встречался',
#  'активно тоже встречался',
#  'часто приходили',
#  'вечером ездили',
#  'вдвоём спали',
#  'ездили вечером вдвоём',
#  'исправно судился',
#  'напечатали где',
#  'была специально',
#  'сильно выделялся',
#  'потом идут',
#  'мог собственно',
#  'однозначно смотрелась',
#  'смотрелась однозначно там',
#  'было хорошо',
#  'тогда было',
#  'уже тогда было',
#  'было уже тогда понятно',
#  'редко спорят',
#  'редко сидят',
#  'спорят редко спокойно',
#  'сидят редко спокойно',
#  'сидят спокойно редко очень',
#  'потом идут',
#  'отмечает потому',
#  'прекрасно знает',
#  'сперва позвонил',
#  'сейчас сяду',
#  'сюда зашли',
#  'вдвоём сюда зашли',
#  'очень доверяю',
#  'часто опускается',
#  'привычно переобувается',
#  'здесь стоят',
#  'быстро боится',
#  'ходит быстро',
#  'увидела вживую',
#  'тут интересуется',
#  'разочаровываю пока',
#  'поверх уволила',
#  'укладывал поверх',
#  'сейчас стоит',
#  'уже стояли',
#  'тоже планирует',
#  'сейчас сподвигаю',
#  'женственно одевается',
#  'женственно говорит',
#  'умеет жёстко',
#  'быстро принимает',
#  'всегда поучает',
#  'потом приезжает',
#  'летит потом',
#  'полностью устраивает',
#  'несколько повторяет',
#  'устраивает полностью несколько',
#  'никогда скрывал',
#  'потом добавляет',
#  'была абсолютно',
#  'тоже считает',
#  'обеспечила более',
#  'иначе было',
#  'было иначе гораздо',
#  'по-другому складываются',
#  'тут расправлялись',
#  'торжественно проводится',
#  'тоже собиралась',
#  'сюда люблю',
#  'люблю сюда здесь',
#  'уже говорит',
#  'сегодня искупаемся',
#  'поедем сегодня',
#  'туда сегодня искупаемся',
#  'туда выпьем',
#  'поедем сегодня туда',
#  'всегда говорит',
#  'плодотворно сказывается',
#  'нисколько поменял',
#  'накоротке может',
#  'было потому',
#  'сделалось сегодня',
#  'считает сразу',
#  'фактически предостерёг',
#  'знаю очень',
#  'знаю очень давно',
#  'сейчас получается',
#  'получается сейчас пока',
#  'обстоят неважно',
#  'прекрасно знает',
#  'наверное пойдёт',
#  'буду довольно',
#  'куда-то иду',
#  'фотографируют куда-то',
#  'по-прежнему хожу',
#  'где-то ужинаем',
#  'было тяжело',
#  'как-то подумала',
#  'как-то отпустило',
#  'массово репостят',
#  'теперь рассматривают',
#  'скоро посадят',
#  'узнала недавно',
#  'там оказалась',
#  'непонятно говорит',
#  'оказалась там непонятно',
#  'смотрю иногда',
#  'очень люблю',
#  'там бывают',
#  'почему-то пользовался',
#  'попёрло сейчас',
#  'говорит очень',
#  'получится вообще',
#  'ведёт намеренно',
#  'уже спрашивали',
#  'уже ведёт',
#  'информационно говорит',
#  'наоборот избегают',
#  'всячески наоборот избегают',
#  'сейчас существуют',
#  'уже был',
#  'помогло уже',
#  'была публично',
#  'немного вывалилась',
#  'немножко опередила',
#  'повезло немножко']

# %%
find_VN_tran(toks)
# Out:
# ['развернула бурную деятельность',
#  'занял место',
#  'возглавил якутию',
#  'подвело разгар',
#  'развернула бурную деятельность',
#  'занял место',
#  'возглавил якутию',
#  'подвело разгар',
#  'разыграл национальную карту',
#  'делала упор',
#  'подчёркивает проигрыш',
#  'одобрил пенсионную реформу',
#  'поддержала инициативу',
#  'накрыла россию',
#  'выполняла распоряжение',
#  'подписала распоряжение',
#  'вызвали одобрение',
#  'любит время',
#  'устраивает раз',
#  'устанавливают большую палатку',
#  'покинул пост',
#  'поменял отношение',
#  'дал интервью',
#  'сказал волю',
#  'вызывает волну',
#  'отменила дорогую инаугурацию',
#  'опередила время']

# %%
find_AN(toks)
# Out:
# ['единственной столицей',
#  'бурную деятельность',
#  'городской аппарат',
#  'якутской мэрии',
#  'какое будущее',
#  'якутский бизнесмен',
#  'телефонного разговора',
#  'летней авксентьевой',
#  'партийное руководство',
#  'фёдоров который',
#  'свою кандидатуру',
#  'этой подготовки',
#  'московский парень',
#  'фёдоров один',
#  'дальнейшем развитии',
#  'значительную роль',
#  'личная мотивация',
#  'моя планка',
#  'сам фёдоров',
#  'того заседания',
#  'самого избиркома',
#  'стройная женщина',
#  'темноволосая женщина',
#  'фирменным знаком',
#  'всю жизнь',
#  'муниципального управления',
#  'единой россии',
#  'единую россию',
#  'единственной столицей',
#  'бурную деятельность',
#  'городской аппарат',
#  'якутской мэрии',
#  'какое будущее',
#  'якутский бизнесмен',
#  'телефонного разговора',
#  'летней авксентьевой',
#  'партийное руководство',
#  'фёдоров который',
#  'свою кандидатуру',
#  'этой подготовки',
#  'московский парень',
#  'фёдоров один',
#  'дальнейшем развитии',
#  'значительную роль',
#  'личная мотивация',
#  'моя планка',
#  'сам фёдоров',
#  'того заседания',
#  'самого избиркома',
#  'стройная женщина',
#  'темноволосая женщина',
#  'фирменным знаком',
#  'всю жизнь',
#  'муниципального управления',
#  'единой россии',
#  'фёдоров который',
#  'планёрка штабная',
#  'национальную карту',
#  'якутский фёдоров',
#  'местной лилии',
#  'сардааны местной',
#  'национальном языке',
#  'источник знакомый',
#  'технический кандидат',
#  'технический степан',
#  'все сми',
#  'город маленький',
#  'сам степан',
#  'сам подаруев',
#  'огромное количество',
#  'своей кампании',
#  'избирательной кампании',
#  'приезжего человека',
#  'публичном пространстве',
#  'том числе',
#  'самом деле',
#  'открытые дебаты',
#  'пенсионную реформу',
#  'предвыборной кампании',
#  'единственной женщиной',
#  'первичной узнаваемости',
#  'всю кампанию',
#  'том числе',
#  'меланхоличный народ',
#  'справедливая россия',
#  'общероссийской тенденции',
#  'антиистеблишментская волна',
#  'волна которая',
#  'своё время',
#  'хорошая команда',
#  'предвыборная стратегия',
#  'известный человек',
#  'предвыборной кампании',
#  'организации предвыборной',
#  'первым заместителем',
#  'заместителем ответственным',
#  'городское хозяйство',
#  'республиканской администрации',
#  'эту версию',
#  'одна команда',
#  'ситуация другая',
#  'лыжных штанов',
#  'свою пару',
#  'лишнюю минуту',
#  'предвыборное обещание',
#  'твёрдого покрытия',
#  'публичной плоскости',
#  'идеальный политик',
#  'идеальный популист',
#  'наш работодатель',
#  'городского бюджета',
#  'том числе',
#  'республиканской делегации',
#  'который асфальт',
#  'зимний фестиваль',
#  'муниципального жилья',
#  'городской бюджет',
#  'большая часть',
#  'подростковом возрасте',
#  'женскую природу',
#  'баба которая',
#  'каждому мужику',
#  'эту планёрку',
#  'городскую планёрку',
#  'мягкую конструкцию',
#  'главой республики',
#  'сам фёдоров',
#  'самый город',
#  'крупный город',
#  'вечной мерзлоте',
#  'большую палатку',
#  'губернаторской купели',
#  'своя купель',
#  'большая часть',
#  'том числе',
#  'тот кандидат',
#  'финансовая поддержка',
#  'николаев который',
#  'республиканской администрации',
#  'этот жест',
#  'каком конфликте',
#  'единой россии',
#  'известный политик',
#  'том числе',
#  'новая команда',
#  'рабочая команда',
#  'главная проблема',
#  'предпенсионного возраста',
#  'кандидата предпенсионного',
#  'дальновидный политик',
#  'айсен дальновидный',
#  'усталым человеком',
#  'работа мужская',
#  'огромное число',
#  'честного мэра',
#  'здорового человека',
#  'популярном сайте',
#  'народное творчество',
#  'свой аккаунт',
#  'местное самоуправление',
#  'основного кандидата',
#  'дорогую инаугурацию',
#  'общественном транспорте',
#  'открытую стадию',
#  'доследственная проверка',
#  'подконтрольная гордума',
#  'своей предшественницы',
#  'единой россии',
#  'какого-то строя',
#  'оппозиционный город',
#  'оппозиционный мэр',
#  'существующего строя',
#  'общественный запрос']

# %%
toks
# Out:
# [Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='сентября', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='сентябрь', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сентября', 190, 1),)),
#  Parse(word='года', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='год', score=0.999139, methods_stack=((<DictionaryAnalyzer>, 'года', 1168, 1),)),
#  Parse(word='якутск', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,nomn'), normal_form='якутск', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'якутск', 73, 0),)),
#  Parse(word='стал', tag=OpencorporaTag('VERB,perf,intr masc,sing,past,indc'), normal_form='стать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'стал', 904, 1),)),
#  Parse(word='единственной', tag=OpencorporaTag('ADJF femn,sing,ablt'), normal_form='единственный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'единственной', 671, 11),)),
#  Parse(word='региональной', tag=OpencorporaTag('ADJF femn,sing,loct'), normal_form='региональный', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'региональной', 60, 13),)),
#  Parse(word='столицей', tag=OpencorporaTag('NOUN,inan,femn sing,ablt'), normal_form='столица', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'столицей', 141, 4),)),
#  Parse(word='где', tag=OpencorporaTag('ADVB,Ques'), normal_form='где', score=0.636363, methods_stack=((<DictionaryAnalyzer>, 'где', 1130, 0),)),
#  Parse(word='мэром', tag=OpencorporaTag('NOUN,anim,masc sing,ablt'), normal_form='мэр', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мэром', 52, 4),)),
#  Parse(word='был', tag=OpencorporaTag('VERB,impf,intr masc,sing,past,indc'), normal_form='быть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'был', 587, 4),)),
#  Parse(word='избран', tag=OpencorporaTag('ADJS,Qual masc,sing'), normal_form='избранный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'избран', 328, 27),)),
#  Parse(word='представитель', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='представитель', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'представитель', 121, 0),)),
#  Parse(word='оппозиции', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='оппозиция', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'оппозиции', 40, 1),)),
#  Parse(word='летняя', tag=OpencorporaTag('ADJF femn,sing,nomn'), normal_form='летний', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'летняя', 382, 7),)),
#  Parse(word='сардана', tag=OpencorporaTag('PRTS,perf,past,pssv femn,sing'), normal_form='сардать', score=0.18867924528301888, methods_stack=((<DictionaryAnalyzer>, 'дана', 843, 72), (<UnknownPrefixAnalyzer>, 'сар'))),
#  Parse(word='авксентьева', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='авксентьев', score=0.32499999999999996, methods_stack=((<FakeDictionary>, 'авксентьева', 36, 1), (<KnownSuffixAnalyzer>, 'тьева'))),
#  Parse(word='обошла', tag=OpencorporaTag('VERB,perf,tran femn,sing,past,indc'), normal_form='обойти', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'обошла', 2163, 2),)),
#  Parse(word='единоросса', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='единоросс', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'единоросса', 52, 1),)),
#  Parse(word='александра', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='александр', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 26, 1),)),
#  Parse(word='саввинова', tag=OpencorporaTag('ADJS,Qual femn,sing'), normal_form='саввиновый', score=0.5007385524372229, methods_stack=((<DictionaryAnalyzer>, 'нова', 405, 55), (<UnknownPrefixAnalyzer>, 'савви'))),
#  Parse(word='поддержанного', tag=OpencorporaTag('PRTF,perf,tran,past,pssv masc,sing,gent'), normal_form='поддержать', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'поддержанного', 845, 43),)),
#  Parse(word='губернатором', tag=OpencorporaTag('NOUN,anim,masc sing,ablt'), normal_form='губернатор', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'губернатором', 52, 4),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='стала', tag=OpencorporaTag('VERB,perf,intr femn,sing,past,indc'), normal_form='стать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'стала', 904, 2),)),
#  Parse(word='первой', tag=OpencorporaTag('ADJF,Anum femn,sing,gent'), normal_form='один', score=0.423076, methods_stack=((<DictionaryAnalyzer>, 'первой', 2198, 34),)),
#  Parse(word='женщиной', tag=OpencorporaTag('NOUN,anim,femn sing,ablt'), normal_form='женщина', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'женщиной', 53, 4),)),
#  Parse(word='градоначальником', tag=OpencorporaTag('NOUN,anim,masc sing,ablt'), normal_form='градоначальник', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'градоначальником', 2, 4),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='истории', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='история', score=0.463414, methods_stack=((<DictionaryAnalyzer>, 'истории', 40, 6),)),
#  Parse(word='города', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='город', score=0.989949, methods_stack=((<DictionaryAnalyzer>, 'города', 1188, 1),)),
#  Parse(word='после', tag=OpencorporaTag('PREP'), normal_form='после', score=0.857142, methods_stack=((<DictionaryAnalyzer>, 'после', 24, 0),)),
#  Parse(word='избрания', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='избрание', score=0.866666, methods_stack=((<DictionaryAnalyzer>, 'избрания', 76, 2),)),
#  Parse(word='авксентьева', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='авксентьев', score=0.32499999999999996, methods_stack=((<FakeDictionary>, 'авксентьева', 36, 1), (<KnownSuffixAnalyzer>, 'тьева'))),
#  Parse(word='развернула', tag=OpencorporaTag('VERB,perf,tran femn,sing,past,indc'), normal_form='развернуть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'развернула', 2633, 2),)),
#  Parse(word='бурную', tag=OpencorporaTag('ADJF,Qual femn,sing,accs'), normal_form='бурный', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'бурную', 12, 10),)),
#  Parse(word='деятельность', tag=OpencorporaTag('NOUN,inan,femn sing,accs'), normal_form='деятельность', score=0.611111, methods_stack=((<DictionaryAnalyzer>, 'деятельность', 13, 3),)),
#  Parse(word='направленную', tag=OpencorporaTag('PRTF,perf,tran,past,pssv,Adjx femn,sing,accs'), normal_form='направить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'направленную', 1527, 52),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='исполнение', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='исполнение', score=0.8, methods_stack=((<DictionaryAnalyzer>, 'исполнение', 76, 6),)),
#  Parse(word='народного', tag=OpencorporaTag('ADJF,Qual neut,sing,gent'), normal_form='народный', score=0.75, methods_stack=((<DictionaryAnalyzer>, 'народного', 12, 15),)),
#  Parse(word='заказа', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='заказ', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'заказа', 33, 1),)),
#  Parse(word='принялась', tag=OpencorporaTag('VERB,perf,intr femn,sing,past,indc'), normal_form='приняться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'принялась', 2560, 2),)),
#  Parse(word='сокращать', tag=OpencorporaTag('INFN,impf,tran'), normal_form='сокращать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сокращать', 206, 0),)),
#  Parse(word='расходы', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='расход', score=0.7, methods_stack=((<DictionaryAnalyzer>, 'расходы', 33, 6),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='городской', tag=OpencorporaTag('ADJF masc,sing,nomn'), normal_form='городской', score=0.14285714285714285, methods_stack=((<DictionaryAnalyzer>, 'городской', 575, 0),)),
#  Parse(word='аппарат', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='аппарат', score=0.583333, methods_stack=((<DictionaryAnalyzer>, 'аппарат', 33, 0),)),
#  Parse(word='увольнять', tag=OpencorporaTag('INFN,impf,tran'), normal_form='увольнять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'увольнять', 206, 0),)),
#  Parse(word='сомнительных', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='сомнительный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'сомнительных', 216, 21),)),
#  Parse(word='чиновников', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='чиновник', score=0.793103, methods_stack=((<DictionaryAnalyzer>, 'чиновников', 2, 7),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='подрядчиков', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='подрядчик', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'подрядчиков', 2, 7),)),
#  Parse(word='распродавать', tag=OpencorporaTag('INFN,impf,tran'), normal_form='распродавать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'распродавать', 841, 0),)),
#  Parse(word='записанные', tag=OpencorporaTag('PRTF,perf,tran,past,pssv plur,nomn'), normal_form='записать', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'записанные', 916, 62),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='мэрию', tag=OpencorporaTag('NOUN,inan,femn sing,accs'), normal_form='мэрия', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мэрию', 40, 3),)),
#  Parse(word='дорогие', tag=OpencorporaTag('ADJF,Qual plur,nomn'), normal_form='дорогой', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'дорогие', 1327, 20),)),
#  Parse(word='машины', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='машина', score=0.921052, methods_stack=((<DictionaryAnalyzer>, 'машины', 55, 1),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='результате', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='результат', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'результате', 33, 5),)),
#  Parse(word='авксентьева', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='авксентьев', score=0.32499999999999996, methods_stack=((<FakeDictionary>, 'авксентьева', 36, 1), (<KnownSuffixAnalyzer>, 'тьева'))),
#  Parse(word='стала', tag=OpencorporaTag('VERB,perf,intr femn,sing,past,indc'), normal_form='стать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'стала', 904, 2),)),
#  Parse(word='общероссийской', tag=OpencorporaTag('ADJF femn,sing,gent'), normal_form='общероссийский', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'общероссийской', 16, 8),)),
#  Parse(word='знаменитостью', tag=OpencorporaTag('NOUN,inan,femn sing,ablt'), normal_form='знаменитость', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'знаменитостью', 13, 4),)),
#  Parse(word='а', tag=OpencorporaTag('CONJ'), normal_form='а', score=0.996696, methods_stack=((<DictionaryAnalyzer>, 'а', 20, 0),)),
#  Parse(word='успехами', tag=OpencorporaTag('NOUN,inan,masc plur,ablt'), normal_form='успех', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'успехами', 19, 10),)),
#  Parse(word='якутской', tag=OpencorporaTag('ADJF femn,sing,gent'), normal_form='якутский', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'якутской', 16, 8),)),
#  Parse(word='мэрии', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='мэрия', score=0.444444, methods_stack=((<DictionaryAnalyzer>, 'мэрии', 40, 1),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='интернете', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='интернет', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'интернете', 33, 5),)),
#  Parse(word='даже', tag=OpencorporaTag('PRCL'), normal_form='даже', score=0.833333, methods_stack=((<DictionaryAnalyzer>, 'даже', 22, 0),)),
#  Parse(word='заинтересовались', tag=OpencorporaTag('VERB,perf,intr plur,past,indc'), normal_form='заинтересоваться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'заинтересовались', 729, 4),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='администрации', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='администрация', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'администрации', 40, 1),)),
#  Parse(word='президента', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='президент', score=0.904, methods_stack=((<DictionaryAnalyzer>, 'президента', 52, 1),)),
#  Parse(word='спецкор', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='спецкор', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'спецкор', 52, 0),)),
#  Parse(word='медузы', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='медуза', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'медузы', 53, 1),)),
#  Parse(word='таисия', tag=OpencorporaTag('NOUN,anim,femn,Name sing,nomn'), normal_form='таисия', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'таисия', 63, 0),)),
#  Parse(word='бекбулатова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='бекбулатов', score=0.3304647160068847, methods_stack=((<DictionaryAnalyzer>, 'булатова', 36, 1), (<UnknownPrefixAnalyzer>, 'бек'))),
#  Parse(word='отправилась', tag=OpencorporaTag('VERB,perf,intr femn,sing,past,indc'), normal_form='отправиться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'отправилась', 754, 2),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='якутск', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,nomn'), normal_form='якутск', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'якутск', 73, 0),)),
#  Parse(word='чтобы', tag=OpencorporaTag('CONJ'), normal_form='чтобы', score=0.888888, methods_stack=((<DictionaryAnalyzer>, 'чтобы', 20, 0),)),
#  Parse(word='понять', tag=OpencorporaTag('INFN,perf,tran'), normal_form='понять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'понять', 1322, 0),)),
#  Parse(word='как', tag=OpencorporaTag('CONJ'), normal_form='как', score=0.875, methods_stack=((<DictionaryAnalyzer>, 'как', 1673, 0),)),
#  Parse(word='авксентьевой', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,gent'), normal_form='авксентьев', score=0.19382022471910115, methods_stack=((<FakeDictionary>, 'авксентьевой', 36, 7), (<KnownSuffixAnalyzer>, 'ьевой'))),
#  Parse(word='удалось', tag=OpencorporaTag('VERB,perf,intr neut,sing,past,indc'), normal_form='удаться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'удалось', 648, 3),)),
#  Parse(word='победить', tag=OpencorporaTag('INFN,perf,tran'), normal_form='победить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'победить', 860, 0),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='какое', tag=OpencorporaTag('ADJF,Apro neut,sing,accs'), normal_form='какой', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'какое', 1676, 17),)),
#  Parse(word='будущее', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='будущее', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'будущее', 501, 3),)),
#  Parse(word='её', tag=OpencorporaTag('NPRO,femn,3per,Anph sing,gent'), normal_form='она', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'её', 2209, 1),)),
#  Parse(word='ждёт', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='ждать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'ждёт', 929, 5),)),
#  Parse(word='августа', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='август', score=0.941176, methods_stack=((<DictionaryAnalyzer>, 'августа', 33, 1),)),
#  Parse(word='года', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='год', score=0.999139, methods_stack=((<DictionaryAnalyzer>, 'года', 1168, 1),)),
#  Parse(word='за', tag=OpencorporaTag('PREP'), normal_form='за', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'за', 24, 0),)),
#  Parse(word='пять', tag=OpencorporaTag('NUMR nomn'), normal_form='пять', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'пять', 889, 0),)),
#  Parse(word='недель', tag=OpencorporaTag('NOUN,inan,femn plur,gent'), normal_form='неделя', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'недель', 335, 8),)),
#  Parse(word='до', tag=OpencorporaTag('PREP'), normal_form='до', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'до', 24, 0),)),
#  Parse(word='выборов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='выбор', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'выборов', 33, 7),)),
#  Parse(word='главы', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='глава', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'главы', 513, 1),)),
#  Parse(word='якутска', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,gent'), normal_form='якутск', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'якутска', 73, 1),)),
#  Parse(word='сардане', tag=OpencorporaTag('NOUN,anim,masc,Name sing,loct'), normal_form='сардан', score=0.10606060606060606, methods_stack=((<DictionaryAnalyzer>, 'дане', 26, 5), (<UnknownPrefixAnalyzer>, 'сар'))),
#  Parse(word='авксентьевой', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,gent'), normal_form='авксентьев', score=0.19382022471910115, methods_stack=((<FakeDictionary>, 'авксентьевой', 36, 7), (<KnownSuffixAnalyzer>, 'ьевой'))),
#  Parse(word='позвонили', tag=OpencorporaTag('VERB,perf,intr plur,past,indc'), normal_form='позвонить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'позвонили', 752, 4),)),
#  Parse(word='голос', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='голос', score=0.73913, methods_stack=((<DictionaryAnalyzer>, 'голос', 1175, 0),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='телефонной', tag=OpencorporaTag('ADJF,Qual femn,sing,gent'), normal_form='телефонный', score=0.571428, methods_stack=((<DictionaryAnalyzer>, 'телефонной', 12, 8),)),
#  Parse(word='трубке', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='трубка', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'трубке', 8, 2),)),
#  Parse(word='объявил', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='объявить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'объявил', 647, 1),)),
#  Parse(word='ну', tag=OpencorporaTag('PRCL'), normal_form='ну', score=0.652173, methods_stack=((<DictionaryAnalyzer>, 'ну', 22, 0),)),
#  Parse(word='все', tag=OpencorporaTag('ADJF,Apro plur,nomn'), normal_form='весь', score=0.357142, methods_stack=((<DictionaryAnalyzer>, 'все', 703, 20),)),
#  Parse(word='мать', tag=OpencorporaTag('NOUN,anim,femn sing,nomn'), normal_form='мать', score=0.818181, methods_stack=((<DictionaryAnalyzer>, 'мать', 1917, 0),)),
#  Parse(word='ты', tag=OpencorporaTag('NPRO,2per sing,nomn'), normal_form='ты', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'ты', 2920, 0),)),
#  Parse(word='мэр', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='мэр', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мэр', 52, 0),)),
#  Parse(word='звонил', tag=OpencorporaTag('VERB,impf,intr masc,sing,past,indc'), normal_form='звонить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'звонил', 338, 7),)),
#  Parse(word='якутский', tag=OpencorporaTag('ADJF masc,sing,nomn'), normal_form='якутский', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'якутский', 16, 0),)),
#  Parse(word='бизнесмен', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='бизнесмен', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'бизнесмен', 52, 0),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='депутат', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='депутат', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'депутат', 52, 0),)),
#  Parse(word='регионального', tag=OpencorporaTag('ADJF neut,sing,gent'), normal_form='региональный', score=0.714285, methods_stack=((<DictionaryAnalyzer>, 'регионального', 60, 15),)),
#  Parse(word='парламента', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='парламент', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'парламента', 33, 1),)),
#  Parse(word='владимир', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='владимир', score=0.948717, methods_stack=((<DictionaryAnalyzer>, 'владимир', 26, 0),)),
#  Parse(word='фёдоров', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='фёдоров', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'фёдоров', 36, 0),)),
#  Parse(word='вплоть', tag=OpencorporaTag('ADVB'), normal_form='вплоть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'вплоть', 3, 0),)),
#  Parse(word='до', tag=OpencorporaTag('PREP'), normal_form='до', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'до', 24, 0),)),
#  Parse(word='утра', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='утро', score=0.962962, methods_stack=((<DictionaryAnalyzer>, 'утра', 54, 1),)),
#  Parse(word='августа', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='август', score=0.941176, methods_stack=((<DictionaryAnalyzer>, 'августа', 33, 1),)),
#  Parse(word='один', tag=OpencorporaTag('ADJF,Apro masc,sing,nomn'), normal_form='один', score=0.629629, methods_stack=((<DictionaryAnalyzer>, 'один', 2198, 0),)),
#  Parse(word='из', tag=OpencorporaTag('PREP'), normal_form='из', score=0.999661, methods_stack=((<DictionaryAnalyzer>, 'из', 375, 0),)),
#  Parse(word='главных', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='главный', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'главных', 214, 21),)),
#  Parse(word='претендентов', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='претендент', score=0.928571, methods_stack=((<DictionaryAnalyzer>, 'претендентов', 52, 7),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='пост', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='пост', score=0.911764, methods_stack=((<DictionaryAnalyzer>, 'пост', 111, 3),)),
#  Parse(word='мэра', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='мэр', score=0.842105, methods_stack=((<DictionaryAnalyzer>, 'мэра', 52, 1),)),
#  Parse(word='якутска', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,gent'), normal_form='якутск', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'якутска', 73, 1),)),
#  Parse(word='за', tag=OpencorporaTag('PREP'), normal_form='за', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'за', 24, 0),)),
#  Parse(word='несколько', tag=OpencorporaTag('ADVB'), normal_form='несколько', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'несколько', 3, 0),)),
#  Parse(word='дней', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='день', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'дней', 1267, 7),)),
#  Parse(word='до', tag=OpencorporaTag('PREP'), normal_form='до', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'до', 24, 0),)),
#  Parse(word='телефонного', tag=OpencorporaTag('ADJF,Qual masc,sing,gent'), normal_form='телефонный', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'телефонного', 12, 1),)),
#  Parse(word='разговора', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='разговор', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'разговора', 33, 1),)),
#  Parse(word='именно', tag=OpencorporaTag('PRCL'), normal_form='именно', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'именно', 22, 0),)),
#  Parse(word='он', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,nomn'), normal_form='он', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'он', 2208, 0),)),
#  Parse(word='предложил', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='предложить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'предложил', 634, 1),)),
#  Parse(word='летней', tag=OpencorporaTag('ADJF femn,sing,gent'), normal_form='летний', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'летней', 382, 8),)),
#  Parse(word='сардане', tag=OpencorporaTag('NOUN,anim,masc,Name sing,loct'), normal_form='сардан', score=0.10606060606060606, methods_stack=((<DictionaryAnalyzer>, 'дане', 26, 5), (<UnknownPrefixAnalyzer>, 'сар'))),
#  Parse(word='авксентьевой', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,gent'), normal_form='авксентьев', score=0.19382022471910115, methods_stack=((<FakeDictionary>, 'авксентьевой', 36, 7), (<KnownSuffixAnalyzer>, 'ьевой'))),
#  Parse(word='принять', tag=OpencorporaTag('INFN,perf,tran'), normal_form='принять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'принять', 897, 0),)),
#  Parse(word='участие', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='участие', score=0.890909, methods_stack=((<DictionaryAnalyzer>, 'участие', 76, 6),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='предполагая', tag=OpencorporaTag('GRND,impf,tran pres'), normal_form='предполагать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'предполагая', 878, 94),)),
#  Parse(word='что', tag=OpencorporaTag('CONJ'), normal_form='что', score=0.791044, methods_stack=((<DictionaryAnalyzer>, 'что', 3046, 0),)),
#  Parse(word='сам', tag=OpencorporaTag('ADJF,Apro masc,sing,nomn'), normal_form='сам', score=0.973684, methods_stack=((<DictionaryAnalyzer>, 'сам', 2709, 0),)),
#  Parse(word='этого', tag=OpencorporaTag('NPRO,neut sing,gent'), normal_form='это', score=0.971098, methods_stack=((<DictionaryAnalyzer>, 'этого', 3098, 1),)),
#  Parse(word='сделать', tag=OpencorporaTag('INFN,perf,tran'), normal_form='сделать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сделать', 614, 0),)),
#  Parse(word='не', tag=OpencorporaTag('PRCL'), normal_form='не', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'не', 22, 0),)),
#  Parse(word='сможет', tag=OpencorporaTag('VERB,perf,intr sing,3per,futr,indc'), normal_form='смочь', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сможет', 857, 9),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='году', tag=OpencorporaTag('NOUN,inan,masc sing,loc2'), normal_form='год', score=0.95601, methods_stack=((<DictionaryAnalyzer>, 'году', 1168, 6),)),
#  Parse(word='владимир', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='владимир', score=0.948717, methods_stack=((<DictionaryAnalyzer>, 'владимир', 26, 0),)),
#  Parse(word='фёдоров', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='фёдоров', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'фёдоров', 36, 0),)),
#  Parse(word='уже', tag=OpencorporaTag('ADVB'), normal_form='уже', score=0.692307, methods_stack=((<DictionaryAnalyzer>, 'уже', 3, 0),)),
#  Parse(word='участвовал', tag=OpencorporaTag('VERB,impf,intr masc,sing,past,indc'), normal_form='участвовать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'участвовал', 172, 7),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='мэра', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='мэр', score=0.842105, methods_stack=((<DictionaryAnalyzer>, 'мэра', 52, 1),)),
#  Parse(word='якутска', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,gent'), normal_form='якутск', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'якутска', 73, 1),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='качестве', tag=OpencorporaTag('NOUN,inan,neut sing,loct'), normal_form='качество', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'качестве', 54, 5),)),
#  Parse(word='самовыдвиженца', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='самовыдвиженец', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'самовыдвиженца', 38, 1),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='занял', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='занять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'занял', 1322, 1),)),
#  Parse(word='второе', tag=OpencorporaTag('ADJF,Anum neut,sing,nomn'), normal_form='два', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'второе', 1248, 33),)),
#  Parse(word='место', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='место', score=0.707964, methods_stack=((<DictionaryAnalyzer>, 'место', 54, 3),)),
#  Parse(word='набрав', tag=OpencorporaTag('GRND,perf,tran past'), normal_form='набрать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'набрав', 1287, 69),)),
#  Parse(word='голосов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='голос', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'голосов', 1175, 8),)),
#  Parse(word='выиграл', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='выиграть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'выиграл', 614, 1),)),
#  Parse(word='выборы', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='выбор', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'выборы', 33, 6),)),
#  Parse(word='единоросс', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='единоросс', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'единоросс', 52, 0),)),
#  Parse(word='айсен', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='айсен', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'айсен', 26, 0),)),
#  Parse(word='николаев', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,nomn'), normal_form='николаев', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'николаев', 32, 0),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='следующих', tag=OpencorporaTag('ADJF plur,gent'), normal_form='следующий', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'следующих', 162, 21),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='году', tag=OpencorporaTag('NOUN,inan,masc sing,loc2'), normal_form='год', score=0.95601, methods_stack=((<DictionaryAnalyzer>, 'году', 1168, 6),)),
#  Parse(word='фёдоров', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='фёдоров', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'фёдоров', 36, 0),)),
#  Parse(word='поддержал', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='поддержать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'поддержал', 845, 1),)),
#  Parse(word='николаева', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,gent'), normal_form='николаев', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'николаева', 32, 1),)),
#  Parse(word='рассчитывая', tag=OpencorporaTag('GRND,impf,intr pres'), normal_form='рассчитывать', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'рассчитывая', 15, 67),)),
#  Parse(word='что', tag=OpencorporaTag('CONJ'), normal_form='что', score=0.791044, methods_stack=((<DictionaryAnalyzer>, 'что', 3046, 0),)),
#  Parse(word='того', tag=OpencorporaTag('ADJF,Apro,Subx,Anph neut,sing,gent'), normal_form='тот', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'того', 2900, 14),)),
#  Parse(word='быстро', tag=OpencorporaTag('ADVB'), normal_form='быстро', score=0.954545, methods_stack=((<DictionaryAnalyzer>, 'быстро', 3, 0),)),
#  Parse(word='повысят', tag=OpencorporaTag('VERB,perf,tran plur,3per,futr,indc'), normal_form='повысить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'повысят', 549, 10),)),
#  Parse(word='до', tag=OpencorporaTag('PREP'), normal_form='до', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'до', 24, 0),)),
#  Parse(word='главы', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='глава', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'главы', 513, 1),)),
#  Parse(word='республики', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='республика', score=0.988888, methods_stack=((<DictionaryAnalyzer>, 'республики', 43, 1),)),
#  Parse(word='а', tag=OpencorporaTag('CONJ'), normal_form='а', score=0.996696, methods_stack=((<DictionaryAnalyzer>, 'а', 20, 0),)),
#  Parse(word='сам', tag=OpencorporaTag('ADJF,Apro masc,sing,nomn'), normal_form='сам', score=0.973684, methods_stack=((<DictionaryAnalyzer>, 'сам', 2709, 0),)),
#  Parse(word='он', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,nomn'), normal_form='он', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'он', 2208, 0),)),
#  Parse(word='после', tag=OpencorporaTag('PREP'), normal_form='после', score=0.857142, methods_stack=((<DictionaryAnalyzer>, 'после', 24, 0),)),
#  Parse(word='этого', tag=OpencorporaTag('NPRO,neut sing,gent'), normal_form='это', score=0.971098, methods_stack=((<DictionaryAnalyzer>, 'этого', 3098, 1),)),
#  Parse(word='без', tag=OpencorporaTag('PREP'), normal_form='без', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'без', 375, 0),)),
#  Parse(word='проблем', tag=OpencorporaTag('NOUN,inan,femn plur,gent'), normal_form='проблема', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'проблем', 55, 8),)),
#  Parse(word='изберётся', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='избраться', score=0.5128205128205128, methods_stack=((<DictionaryAnalyzer>, 'берётся', 529, 5), (<UnknownPrefixAnalyzer>, 'из'))),
#  Parse(word='мэром', tag=OpencorporaTag('NOUN,anim,masc sing,ablt'), normal_form='мэр', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мэром', 52, 4),)),
#  Parse(word='расчёт', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='расчёт', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'расчёт', 33, 0),)),
#  Parse(word='оправдался', tag=OpencorporaTag('VERB,perf,intr masc,sing,past,indc'), normal_form='оправдаться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'оправдался', 615, 1),)),
#  Parse(word='но', tag=OpencorporaTag('CONJ'), normal_form='но', score=0.998721, methods_stack=((<DictionaryAnalyzer>, 'но', 20, 0),)),
#  Parse(word='лишь', tag=OpencorporaTag('PRCL'), normal_form='лишь', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'лишь', 22, 0),)),
#  Parse(word='отчасти', tag=OpencorporaTag('ADVB'), normal_form='отчасти', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'отчасти', 3, 0),)),
#  Parse(word='айсен', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='айсен', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'айсен', 26, 0),)),
#  Parse(word='николаев', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,nomn'), normal_form='николаев', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'николаев', 32, 0),)),
#  Parse(word='действительно', tag=OpencorporaTag('ADVB'), normal_form='действительно', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'действительно', 3, 0),)),
#  Parse(word='возглавил', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='возглавить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'возглавил', 753, 1),)),
#  Parse(word='якутию', tag=OpencorporaTag('NOUN,inan,femn,Sgtm,Geox sing,accs'), normal_form='якутия', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'якутию', 70, 3),)),
#  Parse(word='но', tag=OpencorporaTag('CONJ'), normal_form='но', score=0.998721, methods_stack=((<DictionaryAnalyzer>, 'но', 20, 0),)),
#  Parse(word='республиканские', tag=OpencorporaTag('ADJF plur,nomn'), normal_form='республиканский', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'республиканские', 16, 20),)),
#  Parse(word='власти', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='власть', score=0.882352, methods_stack=((<DictionaryAnalyzer>, 'власти', 13, 1),)),
#  Parse(word='поддержали', tag=OpencorporaTag('VERB,perf,tran plur,past,indc'), normal_form='поддержать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'поддержали', 845, 4),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='качестве', tag=OpencorporaTag('NOUN,inan,neut sing,loct'), normal_form='качество', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'качестве', 54, 5),)),
#  Parse(word='кандидата', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='кандидат', score=0.833333, methods_stack=((<DictionaryAnalyzer>, 'кандидата', 1685, 1),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='мэры', tag=OpencorporaTag('NOUN,anim,masc plur,nomn'), normal_form='мэр', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мэры', 52, 6),)),
#  Parse(word='не', tag=OpencorporaTag('PRCL'), normal_form='не', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'не', 22, 0),)),
#  Parse(word='фёдорова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='фёдоров', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'фёдорова', 36, 1),)),
#  Parse(word='а', tag=OpencorporaTag('CONJ'), normal_form='а', score=0.996696, methods_stack=((<DictionaryAnalyzer>, 'а', 20, 0),)),
#  Parse(word='единоросса', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='единоросс', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'единоросса', 52, 1),)),
#  Parse(word='спикера', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='спикер', score=0.777777, methods_stack=((<DictionaryAnalyzer>, 'спикера', 52, 1),)),
#  Parse(word='городской', tag=OpencorporaTag('ADJF masc,sing,nomn'), normal_form='городской', score=0.14285714285714285, methods_stack=((<DictionaryAnalyzer>, 'городской', 575, 0),)),
#  Parse(word='думы', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='дума', score=0.894736, methods_stack=((<DictionaryAnalyzer>, 'думы', 55, 1),)),
#  Parse(word='летнего', tag=OpencorporaTag('ADJF neut,sing,gent'), normal_form='летний', score=0.6, methods_stack=((<DictionaryAnalyzer>, 'летнего', 382, 15),)),
#  Parse(word='александра', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='александр', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 26, 1),)),
#  Parse(word='саввинова', tag=OpencorporaTag('ADJS,Qual femn,sing'), normal_form='саввиновый', score=0.5007385524372229, methods_stack=((<DictionaryAnalyzer>, 'нова', 405, 55), (<UnknownPrefixAnalyzer>, 'савви'))),
#  Parse(word='очевидно', tag=OpencorporaTag('CONJ,Prnt'), normal_form='очевидно', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'очевидно', 128, 0),)),
#  Parse(word='он', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,nomn'), normal_form='он', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'он', 2208, 0),)),
#  Parse(word='был', tag=OpencorporaTag('VERB,impf,intr masc,sing,past,indc'), normal_form='быть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'был', 587, 4),)),
#  Parse(word='понятен', tag=OpencorporaTag('ADJS,Qual masc,sing'), normal_form='понятный', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'понятен', 86, 54),)),
#  Parse(word='предсказуем', tag=OpencorporaTag('ADJS,Qual masc,sing'), normal_form='предсказуемый', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'предсказуем', 4, 27),)),
#  Parse(word='они', tag=OpencorporaTag('NPRO,3per,Anph plur,nomn'), normal_form='они', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'они', 2210, 0),)),
#  Parse(word='понимали', tag=OpencorporaTag('VERB,impf,tran plur,past,indc'), normal_form='понимать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'понимали', 836, 10),)),
#  Parse(word='чего', tag=OpencorporaTag('NPRO,neut sing,gent'), normal_form='что', score=0.75, methods_stack=((<DictionaryAnalyzer>, 'чего', 3047, 1),)),
#  Parse(word='от', tag=OpencorporaTag('PREP'), normal_form='от', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'от', 375, 0),)),
#  Parse(word='него', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,gent,Af-p'), normal_form='он', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'него', 2208, 2),)),
#  Parse(word='ждать', tag=OpencorporaTag('INFN,impf,tran'), normal_form='ждать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'ждать', 929, 0),)),
#  Parse(word='это', tag=OpencorporaTag('PRCL'), normal_form='это', score=0.35, methods_stack=((<DictionaryAnalyzer>, 'это', 22, 0),)),
#  Parse(word='же', tag=OpencorporaTag('PRCL'), normal_form='же', score=0.6875, methods_stack=((<DictionaryAnalyzer>, 'же', 22, 0),)),
#  Parse(word='комфортно', tag=OpencorporaTag('ADVB'), normal_form='комфортно', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'комфортно', 3, 0),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='случае', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='случай', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'случае', 175, 5),)),
#  Parse(word='избрания', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='избрание', score=0.866666, methods_stack=((<DictionaryAnalyzer>, 'избрания', 76, 2),)),
#  Parse(word='саввинова', tag=OpencorporaTag('ADJS,Qual femn,sing'), normal_form='саввиновый', score=0.5007385524372229, methods_stack=((<DictionaryAnalyzer>, 'нова', 405, 55), (<UnknownPrefixAnalyzer>, 'савви'))),
#  Parse(word='все', tag=OpencorporaTag('ADJF,Apro plur,nomn'), normal_form='весь', score=0.357142, methods_stack=((<DictionaryAnalyzer>, 'все', 703, 20),)),
#  Parse(word='было', tag=OpencorporaTag('VERB,impf,intr neut,sing,past,indc'), normal_form='быть', score=0.963576, methods_stack=((<DictionaryAnalyzer>, 'было', 587, 6),)),
#  Parse(word='бы', tag=OpencorporaTag('PRCL'), normal_form='бы', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'бы', 22, 0),)),
#  Parse(word='по-другому', tag=OpencorporaTag('ADVB'), normal_form='по-другому', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'по-другому', 3, 0),)),
#  Parse(word='не', tag=OpencorporaTag('PRCL'), normal_form='не', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'не', 22, 0),)),
#  Parse(word='так', tag=OpencorporaTag('CONJ'), normal_form='так', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'так', 20, 0),)),
#  Parse(word='как', tag=OpencorporaTag('CONJ'), normal_form='как', score=0.875, methods_stack=((<DictionaryAnalyzer>, 'как', 1673, 0),)),
#  Parse(word='сейчас', tag=OpencorporaTag('ADVB'), normal_form='сейчас', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сейчас', 3, 0),)),
#  Parse(word='говорит', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='говорить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'говорит', 395, 5),)),
#  Parse(word='собеседник', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='собеседник', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'собеседник', 2, 0),)),
#  Parse(word='медузы', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='медуза', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'медузы', 53, 1),)),
#  Parse(word='работавший', tag=OpencorporaTag('PRTF,impf,intr,past,actv masc,sing,nomn'), normal_form='работать', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'работавший', 15, 40),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='регионе', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='регион', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'регионе', 33, 5),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='выборы', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='выбор', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'выборы', 33, 6),)),
#  Parse(word='года', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='год', score=0.999139, methods_stack=((<DictionaryAnalyzer>, 'года', 1168, 1),)),
#  Parse(word='владимир', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='владимир', score=0.948717, methods_stack=((<DictionaryAnalyzer>, 'владимир', 26, 0),)),
#  Parse(word='фёдоров', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='фёдоров', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'фёдоров', 36, 0),)),
#  Parse(word='пошёл', tag=OpencorporaTag('VERB,perf,intr masc,sing,past,indc'), normal_form='пойти', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'пошёл', 2424, 1),)),
#  Parse(word='от', tag=OpencorporaTag('PREP'), normal_form='от', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'от', 375, 0),)),
#  Parse(word='партии', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='партия', score=0.777777, methods_stack=((<DictionaryAnalyzer>, 'партии', 40, 1),)),
#  Parse(word='родина', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='родина', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'родина', 55, 0),)),
#  Parse(word='это', tag=OpencorporaTag('PRCL'), normal_form='это', score=0.35, methods_stack=((<DictionaryAnalyzer>, 'это', 22, 0),)),
#  Parse(word='его', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,accs'), normal_form='он', score=0.234042, methods_stack=((<DictionaryAnalyzer>, 'его', 2208, 5),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='подвело', tag=OpencorporaTag('VERB,perf,tran neut,sing,past,indc'), normal_form='подвести', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'подвело', 628, 3),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='разгар', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='разгар', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'разгар', 33, 3),)),
#  Parse(word='кампании', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='кампания', score=0.125, methods_stack=((<DictionaryAnalyzer>, 'кампании', 40, 1),)),
#  Parse(word='партийное', tag=OpencorporaTag('ADJF,Subx,Qual neut,sing,nomn'), normal_form='партийный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'партийное', 2285, 14),)),
#  Parse(word='руководство', tag=OpencorporaTag('NOUN,inan,neut sing,nomn'), normal_form='руководство', score=0.829268, methods_stack=((<DictionaryAnalyzer>, 'руководство', 54, 0),)),
#  Parse(word='стало', tag=OpencorporaTag('VERB,perf,intr neut,sing,past,indc'), normal_form='стать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'стало', 904, 3),)),
# ...
#  Parse(word='мать', tag=OpencorporaTag('NOUN,anim,femn sing,nomn'), normal_form='мать', score=0.818181, methods_stack=((<DictionaryAnalyzer>, 'мать', 1917, 0),)),
#  Parse(word='ты', tag=OpencorporaTag('NPRO,2per sing,nomn'), normal_form='ты', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'ты', 2920, 0),)),
#  Parse(word='мэр', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='мэр', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мэр', 52, 0),)),
#  Parse(word='звонил', tag=OpencorporaTag('VERB,impf,intr masc,sing,past,indc'), normal_form='звонить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'звонил', 338, 7),)),
#  Parse(word='якутский', tag=OpencorporaTag('ADJF masc,sing,nomn'), normal_form='якутский', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'якутский', 16, 0),)),
#  Parse(word='бизнесмен', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='бизнесмен', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'бизнесмен', 52, 0),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='депутат', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='депутат', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'депутат', 52, 0),)),
#  Parse(word='регионального', tag=OpencorporaTag('ADJF neut,sing,gent'), normal_form='региональный', score=0.714285, methods_stack=((<DictionaryAnalyzer>, 'регионального', 60, 15),)),
#  Parse(word='парламента', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='парламент', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'парламента', 33, 1),)),
#  Parse(word='владимир', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='владимир', score=0.948717, methods_stack=((<DictionaryAnalyzer>, 'владимир', 26, 0),)),
#  Parse(word='фёдоров', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='фёдоров', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'фёдоров', 36, 0),)),
#  Parse(word='вплоть', tag=OpencorporaTag('ADVB'), normal_form='вплоть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'вплоть', 3, 0),)),
#  Parse(word='до', tag=OpencorporaTag('PREP'), normal_form='до', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'до', 24, 0),)),
#  Parse(word='утра', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='утро', score=0.962962, methods_stack=((<DictionaryAnalyzer>, 'утра', 54, 1),)),
#  Parse(word='августа', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='август', score=0.941176, methods_stack=((<DictionaryAnalyzer>, 'августа', 33, 1),)),
#  Parse(word='один', tag=OpencorporaTag('ADJF,Apro masc,sing,nomn'), normal_form='один', score=0.629629, methods_stack=((<DictionaryAnalyzer>, 'один', 2198, 0),)),
#  Parse(word='из', tag=OpencorporaTag('PREP'), normal_form='из', score=0.999661, methods_stack=((<DictionaryAnalyzer>, 'из', 375, 0),)),
#  Parse(word='главных', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='главный', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'главных', 214, 21),)),
#  Parse(word='претендентов', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='претендент', score=0.928571, methods_stack=((<DictionaryAnalyzer>, 'претендентов', 52, 7),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='пост', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='пост', score=0.911764, methods_stack=((<DictionaryAnalyzer>, 'пост', 111, 3),)),
#  Parse(word='мэра', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='мэр', score=0.842105, methods_stack=((<DictionaryAnalyzer>, 'мэра', 52, 1),)),
#  Parse(word='якутска', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,gent'), normal_form='якутск', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'якутска', 73, 1),)),
#  Parse(word='за', tag=OpencorporaTag('PREP'), normal_form='за', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'за', 24, 0),)),
#  Parse(word='несколько', tag=OpencorporaTag('ADVB'), normal_form='несколько', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'несколько', 3, 0),)),
#  Parse(word='дней', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='день', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'дней', 1267, 7),)),
#  Parse(word='до', tag=OpencorporaTag('PREP'), normal_form='до', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'до', 24, 0),)),
#  Parse(word='телефонного', tag=OpencorporaTag('ADJF,Qual masc,sing,gent'), normal_form='телефонный', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'телефонного', 12, 1),)),
#  Parse(word='разговора', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='разговор', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'разговора', 33, 1),)),
#  Parse(word='именно', tag=OpencorporaTag('PRCL'), normal_form='именно', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'именно', 22, 0),)),
#  Parse(word='он', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,nomn'), normal_form='он', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'он', 2208, 0),)),
#  Parse(word='предложил', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='предложить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'предложил', 634, 1),)),
#  Parse(word='летней', tag=OpencorporaTag('ADJF femn,sing,gent'), normal_form='летний', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'летней', 382, 8),)),
#  Parse(word='сардане', tag=OpencorporaTag('NOUN,anim,masc,Name sing,loct'), normal_form='сардан', score=0.10606060606060606, methods_stack=((<DictionaryAnalyzer>, 'дане', 26, 5), (<UnknownPrefixAnalyzer>, 'сар'))),
#  Parse(word='авксентьевой', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,gent'), normal_form='авксентьев', score=0.19382022471910115, methods_stack=((<FakeDictionary>, 'авксентьевой', 36, 7), (<KnownSuffixAnalyzer>, 'ьевой'))),
#  Parse(word='принять', tag=OpencorporaTag('INFN,perf,tran'), normal_form='принять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'принять', 897, 0),)),
#  Parse(word='участие', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='участие', score=0.890909, methods_stack=((<DictionaryAnalyzer>, 'участие', 76, 6),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='предполагая', tag=OpencorporaTag('GRND,impf,tran pres'), normal_form='предполагать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'предполагая', 878, 94),)),
#  Parse(word='что', tag=OpencorporaTag('CONJ'), normal_form='что', score=0.791044, methods_stack=((<DictionaryAnalyzer>, 'что', 3046, 0),)),
#  Parse(word='сам', tag=OpencorporaTag('ADJF,Apro masc,sing,nomn'), normal_form='сам', score=0.973684, methods_stack=((<DictionaryAnalyzer>, 'сам', 2709, 0),)),
#  Parse(word='этого', tag=OpencorporaTag('NPRO,neut sing,gent'), normal_form='это', score=0.971098, methods_stack=((<DictionaryAnalyzer>, 'этого', 3098, 1),)),
#  Parse(word='сделать', tag=OpencorporaTag('INFN,perf,tran'), normal_form='сделать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сделать', 614, 0),)),
#  Parse(word='не', tag=OpencorporaTag('PRCL'), normal_form='не', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'не', 22, 0),)),
#  Parse(word='сможет', tag=OpencorporaTag('VERB,perf,intr sing,3per,futr,indc'), normal_form='смочь', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сможет', 857, 9),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='году', tag=OpencorporaTag('NOUN,inan,masc sing,loc2'), normal_form='год', score=0.95601, methods_stack=((<DictionaryAnalyzer>, 'году', 1168, 6),)),
#  Parse(word='владимир', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='владимир', score=0.948717, methods_stack=((<DictionaryAnalyzer>, 'владимир', 26, 0),)),
#  Parse(word='фёдоров', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='фёдоров', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'фёдоров', 36, 0),)),
#  Parse(word='уже', tag=OpencorporaTag('ADVB'), normal_form='уже', score=0.692307, methods_stack=((<DictionaryAnalyzer>, 'уже', 3, 0),)),
#  Parse(word='участвовал', tag=OpencorporaTag('VERB,impf,intr masc,sing,past,indc'), normal_form='участвовать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'участвовал', 172, 7),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='мэра', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='мэр', score=0.842105, methods_stack=((<DictionaryAnalyzer>, 'мэра', 52, 1),)),
#  Parse(word='якутска', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,gent'), normal_form='якутск', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'якутска', 73, 1),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='качестве', tag=OpencorporaTag('NOUN,inan,neut sing,loct'), normal_form='качество', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'качестве', 54, 5),)),
#  Parse(word='самовыдвиженца', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='самовыдвиженец', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'самовыдвиженца', 38, 1),)),
#  Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#  Parse(word='занял', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='занять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'занял', 1322, 1),)),
#  Parse(word='второе', tag=OpencorporaTag('ADJF,Anum neut,sing,nomn'), normal_form='два', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'второе', 1248, 33),)),
#  Parse(word='место', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='место', score=0.707964, methods_stack=((<DictionaryAnalyzer>, 'место', 54, 3),)),
#  Parse(word='набрав', tag=OpencorporaTag('GRND,perf,tran past'), normal_form='набрать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'набрав', 1287, 69),)),
#  Parse(word='голосов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='голос', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'голосов', 1175, 8),)),
#  Parse(word='выиграл', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='выиграть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'выиграл', 614, 1),)),
#  Parse(word='выборы', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='выбор', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'выборы', 33, 6),)),
#  Parse(word='единоросс', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='единоросс', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'единоросс', 52, 0),)),
#  Parse(word='айсен', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='айсен', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'айсен', 26, 0),)),
#  Parse(word='николаев', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,nomn'), normal_form='николаев', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'николаев', 32, 0),)),
#  Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#  Parse(word='следующих', tag=OpencorporaTag('ADJF plur,gent'), normal_form='следующий', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'следующих', 162, 21),)),
#  Parse(word='выборах', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,loct'), normal_form='выборы', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'выборах', 133, 5),)),
#  Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#  Parse(word='году', tag=OpencorporaTag('NOUN,inan,masc sing,loc2'), normal_form='год', score=0.95601, methods_stack=((<DictionaryAnalyzer>, 'году', 1168, 6),)),
#  Parse(word='фёдоров', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='фёдоров', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'фёдоров', 36, 0),)),
#  Parse(word='поддержал', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='поддержать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'поддержал', 845, 1),)),
#  Parse(word='николаева', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,gent'), normal_form='николаев', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'николаева', 32, 1),)),
#  Parse(word='рассчитывая', tag=OpencorporaTag('GRND,impf,intr pres'), normal_form='рассчитывать', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'рассчитывая', 15, 67),)),
#  Parse(word='что', tag=OpencorporaTag('CONJ'), normal_form='что', score=0.791044, methods_stack=((<DictionaryAnalyzer>, 'что', 3046, 0),)),
#  Parse(word='того', tag=OpencorporaTag('ADJF,Apro,Subx,Anph neut,sing,gent'), normal_form='тот', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'того', 2900, 14),)),
#  Parse(word='быстро', tag=OpencorporaTag('ADVB'), normal_form='быстро', score=0.954545, methods_stack=((<DictionaryAnalyzer>, 'быстро', 3, 0),)),
#  Parse(word='повысят', tag=OpencorporaTag('VERB,perf,tran plur,3per,futr,indc'), normal_form='повысить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'повысят', 549, 10),)),
#  Parse(word='до', tag=OpencorporaTag('PREP'), normal_form='до', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'до', 24, 0),)),
#  Parse(word='главы', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='глава', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'главы', 513, 1),)),
#  Parse(word='республики', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='республика', score=0.988888, methods_stack=((<DictionaryAnalyzer>, 'республики', 43, 1),)),
#  Parse(word='а', tag=OpencorporaTag('CONJ'), normal_form='а', score=0.996696, methods_stack=((<DictionaryAnalyzer>, 'а', 20, 0),)),
#  Parse(word='сам', tag=OpencorporaTag('ADJF,Apro masc,sing,nomn'), normal_form='сам', score=0.973684, methods_stack=((<DictionaryAnalyzer>, 'сам', 2709, 0),)),
#  Parse(word='он', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,nomn'), normal_form='он', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'он', 2208, 0),)),
#  Parse(word='после', tag=OpencorporaTag('PREP'), normal_form='после', score=0.857142, methods_stack=((<DictionaryAnalyzer>, 'после', 24, 0),)),
#  Parse(word='этого', tag=OpencorporaTag('NPRO,neut sing,gent'), normal_form='это', score=0.971098, methods_stack=((<DictionaryAnalyzer>, 'этого', 3098, 1),)),
#  Parse(word='без', tag=OpencorporaTag('PREP'), normal_form='без', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'без', 375, 0),)),
#  Parse(word='проблем', tag=OpencorporaTag('NOUN,inan,femn plur,gent'), normal_form='проблема', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'проблем', 55, 8),)),
#  Parse(word='изберётся', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='избраться', score=0.5128205128205128, methods_stack=((<DictionaryAnalyzer>, 'берётся', 529, 5), (<UnknownPrefixAnalyzer>, 'из'))),
#  Parse(word='мэром', tag=OpencorporaTag('NOUN,anim,masc sing,ablt'), normal_form='мэр', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мэром', 52, 4),)),
#  Parse(word='расчёт', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='расчёт', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'расчёт', 33, 0),)),
#  Parse(word='оправдался', tag=OpencorporaTag('VERB,perf,intr masc,sing,past,indc'), normal_form='оправдаться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'оправдался', 615, 1),)),
#  ...]

# %% [markdown]
# ## Научпоп

# %%
text2, toks2 = read_txt('text_motova.txt')

# %%
find_AN(toks2)
# Out:
# ['научный журналист',
#  'калифорнийском университете',
#  'доказательной диетологии',
#  'доказательной лекции',
#  'новый формат',
#  'эту книгу',
#  'одном флаконе',
#  'доказательная диетология',
#  'пищеварительная система',
#  'сладкий горький',
#  'солёный горький',
#  'кислый горький',
#  'китайская гастрономия',
#  'питательную еду',
#  'полезную еду',
#  'материнское молоко',
#  'электролитного баланса',
#  'основным материалом',
#  'белком основным',
#  'концентрированном виде',
#  'следующего приёма',
#  'ежедневную еду',
#  'еда незрелая',
#  'многодетная мать',
#  'том числе',
#  'эта капуста',
#  'вкусовая чувствительность',
#  'вкусовая стройность',
#  'эталонное вещество',
#  'химическое вещество',
#  'пищевым красителем',
#  'поддержаниестабильного веса',
#  'наше поведение',
#  'пищевое поведение',
#  'красивой подаче',
#  'меньшем количестве',
#  'французский парадокс',
#  'лучшая приправа',
#  'большая часть',
#  'шоколадному следу',
#  'каждый вид',
#  'привычную еду',
#  'острого перца',
#  'жгучей боли',
#  'такую еду',
#  'острая еда']

# %%
find_VN_tran(toks2)
# Out:
# ['ведёт блог',
#  'чувствуем вкус',
#  'регулируют вес',
#  'написала эту книгу',
#  'дают энергию',
#  'содержит лактозу',
#  'предложите овощи',
#  'отвергает такую еду']

# %%
find_AV(toks2)
# Out:
# ['постоянно учится',
#  'хорошо готовит',
#  'почему толстеют',
#  'останется осторожно',
#  'буквально заставляет',
#  'улавливает буквально',
#  'гораздо уловила',
#  'развивалась эволюционно',
#  'получим достаточно',
#  'сообщает насколько',
#  'поэтому отказываются',
#  'рождаются редко',
#  'попробуйте сегодня',
#  'увлекайтесь избыточно',
#  'много пытайтесь']

# %% [markdown]
# ## Специализированный текст о разработке

# %%
text3, toks3 = read_txt('text_taxi.txt')

# %%
find_VN_tran(toks3)
# Out:
# ['нажимает кнопку',
#  'ранжировали водителей',
#  'используем множество',
#  'забили пул',
#  'добавили отправку',
#  'нашли заказ',
#  'играют роль',
#  'сделали возможность',
#  'сохранили логику',
#  'добавили возможность',
#  'нажмёт кнопку',
#  'требует множество']

# %%
find_AV(toks3)
# Out:
# ['быстро приезжала',
#  'сегодня расскажу',
#  'выбираем наиболее',
#  'поэтому поступает',
#  'сначала определяет',
#  'затем уточняется',
#  'ранжировали уже',
#  'могут вообще',
#  'годится максимально',
#  'лежит хорошо',
#  'вкратце суть',
#  'совсем вписывалось',
#  'пришлось немного',
#  'сразу договорились',
#  'индивидуально попадали',
#  'поэтому добавили',
#  'обрабатывались параллельно',
#  'обрабатывались параллельно попутно',
#  'корректно работает',
#  'корректно появился',
#  'уже работало',
#  'почти уже работало',
#  'работало почти уже почти',
#  'работало почти почти уже потому',
#  'извне могли',
#  'контролировались извне',
#  'тут играют',
#  'происходит сразу',
#  'компенсируется более',
#  'далее последует']

# %%
find_AN(toks3)
# Out:
# ['холостого пробега',
#  'подходящего водителя',
#  'общая архитектура',
#  'конечным автоматом',
#  'жадный подход',
#  'жадный подход',
#  'таком подходе',
#  'таком этапе',
#  'локальном геоиндексе',
#  'прямому радиусу',
#  'этой информации',
#  'лучший вариант',
#  'эта логика',
#  'такое назначение',
#  'жадное назначение',
#  'буферный подход',
#  'жадном подходе',
#  'ближайшего водителя',
#  'повышенном спросе',
#  'жадный подход',
#  'самые часы',
#  'буферное назначение',
#  'известная задача',
#  'комбинаторной оптимизации',
#  'любую задачу',
#  'один исполнитель',
#  'одну работу',
#  'такой задачи',
#  'наша стоимость',
#  'одной стороны',
#  'такую задачу',
#  'венгерский алгоритм',
#  'жадном подходе',
#  'отдельном микросервисе',
#  'жадном подходе',
#  'одной машины',
#  'разумного количества',
#  'жадное назначение',
#  'новом сервисе',
#  'наш сервис',
#  'ту сторону',
#  'конечным автоматом',
#  'буферном диспатче',
#  'один способ',
#  'буферном поиске',
#  'подходящему водителю',
#  'непростая задача']
