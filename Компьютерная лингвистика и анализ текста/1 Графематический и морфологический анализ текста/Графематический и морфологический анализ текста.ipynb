# %% [markdown]
# # HW1: Графематический и морфологический анализ текста

# %%
import pandas as pd
import numpy as np

import pymorphy2
import xml.etree.ElementTree as etree
import opencorpora

morph = pymorphy2.MorphAnalyzer()

# %% [markdown]
# Проверим работу pymorphy2

# %%
morph.parse('матери')
# Out:
# [Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='матерь', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 1),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='мать', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 1),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,datv'), normal_form='матерь', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 2),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,loct'), normal_form='матерь', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 5),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn plur,nomn'), normal_form='матерь', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 379, 6),)),
#  Parse(word='матери', tag=OpencorporaTag('VERB,impf,tran sing,impr,excl'), normal_form='материть', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 463, 11),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,datv'), normal_form='мать', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 2),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn sing,loct'), normal_form='мать', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 5),)),
#  Parse(word='матери', tag=OpencorporaTag('NOUN,anim,femn plur,nomn'), normal_form='мать', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'матери', 1917, 6),))]

# %% [markdown]
# Загружаем корпус:

# %%
corpus = opencorpora.load('annot.opcorpora.no_ambig.xml')

# %%
tokens = corpus.tokens

# %% [markdown]
# Создаем датасет:

# %%
frame = pd.DataFrame({'tokens':[t.source for t in tokens], 
                      'morph_POS':[morph.parse(t.source)[0].tag.POS for t in tokens], 
                      'OC_POS':[t.gramm emes[0] for t in tokens], 
                      'morph':[morph.parse(t.source)[0].tag for t in tokens],
                      'OC':[t.grammemes for t in tokens], 
                      'ambig':[True if len(morph.parse(t.source))>1 else False for t in tokens]})

# %% [markdown]
# Убираем знаки препинания и неопределенные в OpenCorpa слова. Создаем новую таблицу, в которой оставляем только те слова, для которых возможна омонимия.

# %%
frame = frame[frame.OC_POS != 'PNCT']
frame = frame[frame.OC_POS != 'UNKN']
ambigf = frame[frame.ambig == True]
ambigf
# Out:
#                tokens morph_POS OC_POS  \
# 2           злословия      NOUN   NOUN
# 6                язык      NOUN   NOUN
# 8                  ли      PRCL   PRCL
# 9              градус      NOUN   NOUN
# 10          дискуссии      NOUN   NOUN
# 11                  в      PREP   PREP
# 12              новом      ADJF   ADJF
# 18          злословия      NOUN   NOUN
# 21                  в      PREP   PREP
# 22               эфир      NOUN   NOUN
# 23              после      PREP   PREP
# 24             летних      ADJF   ADJF
# 26                  в      PREP   PREP
# 27              новом      ADJF   ADJF
# 30                  В      PREP   PREP
# 31            истории      NOUN   NOUN
# 32          программы      NOUN   NOUN
# 33                это      PRCL   NPRO
# 34                уже      ADVB   ADVB
# 36             первый      ADJF   ADJF
# 41              Потом      ADVB   ADVB
# 42             проект      NOUN   NOUN
# 44                  с      PREP   PREP
# 46           Культуры      NOUN   NOUN
# 48                 на      PREP   PREP
# 49                НТВ      NOUN   NOUN
# 51                Это      PRCL   NPRO
# 53              явных      ADJF   ADJF
# 55                  в      PREP   PREP
# 57                тут      ADVB   ADVB
# ...               ...       ...    ...
# 91978  представителей      NOUN   NOUN
# 91979      еврейского      ADJF   ADJF
# 91980       населения      NOUN   NOUN
# 91982              На      PREP   PREP
# 91983            этом      NPRO   NPRO
# 91988          знания      NOUN   NOUN
# 91991              на      PREP   PREP
# 91996             Под      PREP   PREP
# 92002          дороге      NOUN   NOUN
# 92008               в      PREP   PREP
# 92012          паники      NOUN   NOUN
# 92014           Всего      ADVB   PRCL
# 92021             или      CONJ   CONJ
# 92026               Я      NPRO   NPRO
# 92201             или      CONJ   CONJ
# 92213             Или      CONJ   CONJ
# 92227             Или      CONJ   CONJ
# 92239          меньше      COMP   COMP
# 92280       Ярмольник      NOUN   NOUN
# 92335            тоже      ADVB   PRCL
# 92463          Прошла      VERB   VERB
# 92493               Я      NPRO   NPRO
# 92503               Я      NPRO   NPRO
# 92840          Хокинг      NOUN   NOUN
# 92945        Синдеева      NOUN   NOUN
# 92954        Черчилль      NOUN   NOUN
# 93097        Нарышкин      NOUN   NOUN
# 93117     Вексельберг      NOUN   NOUN
# 93153           Земан      NOUN   NOUN
# 93362            Тоже      ADVB   PRCL
#
#                                          morph  \
# 2                     NOUN,inan,neut sing,gent
# 6                     NOUN,inan,masc sing,accs
# 8                                         PRCL
# 9                     NOUN,inan,masc sing,nomn
# 10                    NOUN,inan,femn sing,gent
# 11                                        PREP
# 12                    ADJF,Qual masc,sing,loct
# 18                    NOUN,inan,neut sing,gent
# 21                                        PREP
# 22                    NOUN,inan,masc sing,accs
# 23                                        PREP
# 24                              ADJF plur,gent
# 26                                        PREP
# 27                    ADJF,Qual masc,sing,loct
# 30                                        PREP
# 31                    NOUN,inan,femn sing,loct
# 32                    NOUN,inan,femn sing,gent
# 33                                        PRCL
# 34                                        ADVB
# 36                    ADJF,Anum masc,sing,nomn
# 41                                        ADVB
# 42                    NOUN,inan,masc sing,nomn
# 44                                        PREP
# 46                    NOUN,inan,femn sing,gent
# 48                                        PREP
# 49     NOUN,inan,neut,Sgtm,Fixd,Orgn sing,nomn
# 51                                        PRCL
# 53                         ADJF,Qual plur,gent
# 55                                        PREP
# 57                                   ADVB,Dmns
# ...                                        ...
# 91978                 NOUN,anim,masc plur,gent
# 91979                      ADJF neut,sing,gent
# 91980                 NOUN,inan,neut sing,gent
# 91982                                     PREP
# 91983                      NPRO,neut sing,loct
# 91988                 NOUN,inan,neut sing,gent
# 91991                                     PREP
# 91996                                     PREP
# 92002                 NOUN,inan,femn sing,datv
# 92008                                     PREP
# 92012                 NOUN,inan,femn sing,gent
# 92014                                     ADVB
# 92021                                     CONJ
# 92026                      NPRO,1per sing,nomn
# 92201                                     CONJ
# 92213                                     CONJ
# 92227                                     CONJ
# 92239                                COMP,Qual
# 92280                 NOUN,inan,masc sing,nomn
# 92335                                     ADVB
# 92463       VERB,perf,tran femn,sing,past,indc
# 92493                      NPRO,1per sing,nomn
# 92503                      NPRO,1per sing,nomn
# 92840                 NOUN,inan,masc sing,nomn
# 92945       NOUN,anim,masc,Sgtm,Surn sing,gent
# 92954       NOUN,inan,masc,Sgtm,Geox sing,nomn
# 93097                 NOUN,inan,femn plur,gent
# 93117            NOUN,inan,masc,Geox sing,nomn
# 93153                 NOUN,inan,masc sing,nomn
# 93362                                     ADVB
#
#                                                       OC  ambig
# 2                         [NOUN, inan, neut, sing, gent]   True
# 6                         [NOUN, inan, masc, sing, accs]   True
# 8                                                 [PRCL]   True
# 9                         [NOUN, inan, masc, sing, nomn]   True
# 10                        [NOUN, inan, femn, sing, gent]   True
# 11                                                [PREP]   True
# 12                        [ADJF, Qual, masc, sing, loct]   True
# 18                        [NOUN, inan, neut, sing, gent]   True
# 21                                                [PREP]   True
# 22                        [NOUN, inan, masc, sing, accs]   True
# 23                                                [PREP]   True
# 24                                    [ADJF, plur, gent]   True
# 26                                                [PREP]   True
# 27                        [ADJF, Qual, masc, sing, loct]   True
# 30                                                [PREP]   True
# 31                        [NOUN, inan, femn, sing, loct]   True
# 32                        [NOUN, inan, femn, sing, gent]   True
# 33                              [NPRO, neut, sing, nomn]   True
# 34                                                [ADVB]   True
# 36                        [ADJF, Anum, masc, sing, nomn]   True
# 41                                                [ADVB]   True
# 42                        [NOUN, inan, masc, sing, nomn]   True
# 44                                                [PREP]   True
# 46                        [NOUN, inan, femn, sing, gent]   True
# 48                                                [PREP]   True
# 49     [NOUN, inan, neut, Sgtm, Fixd, Abbr, Orgn, sin...   True
# 51                              [NPRO, neut, sing, nomn]   True
# 53                              [ADJF, Qual, plur, gent]   True
# 55                                                [PREP]   True
# 57                                          [ADVB, Dmns]   True
# ...                                                  ...    ...
# 91978                     [NOUN, anim, masc, plur, gent]   True
# 91979                           [ADJF, neut, sing, gent]   True
# 91980                     [NOUN, inan, neut, sing, gent]   True
# 91982                                             [PREP]   True
# 91983                           [NPRO, neut, sing, loct]   True
# 91988                     [NOUN, inan, neut, sing, gent]   True
# 91991                                             [PREP]   True
# 91996                                             [PREP]   True
# 92002                     [NOUN, inan, femn, sing, datv]   True
# 92008                                             [PREP]   True
# 92012                     [NOUN, inan, femn, sing, gent]   True
# 92014                                             [PRCL]   True
# 92021                                             [CONJ]   True
# 92026                           [NPRO, 1per, sing, nomn]   True
# 92201                                             [CONJ]   True
# 92213                                             [CONJ]   True
# 92227                                             [CONJ]   True
# 92239                                       [COMP, Qual]   True
# 92280         [NOUN, anim, masc, Sgtm, Surn, sing, nomn]   True
# 92335                                             [PRCL]   True
# 92463         [VERB, perf, tran, femn, sing, past, indc]   True
# 92493                           [NPRO, 1per, sing, nomn]   True
# 92503                           [NPRO, 1per, sing, nomn]   True
# 92840         [NOUN, anim, masc, Sgtm, Surn, sing, nomn]   True
# 92945         [NOUN, anim, femn, Sgtm, Surn, sing, nomn]   True
# 92954         [NOUN, anim, masc, Sgtm, Surn, sing, nomn]   True
# 93097         [NOUN, anim, masc, Sgtm, Surn, sing, nomn]   True
# 93117         [NOUN, anim, masc, Sgtm, Surn, sing, nomn]   True
# 93153         [NOUN, anim, masc, Sgtm, Surn, sing, nomn]   True
# 93362                                             [PRCL]   True
#
# [29623 rows x 6 columns]

# %%
def check_homonimy(row):
    if row['OC_POS']=='LATN':
        if 'LATN' not in row['morph']:
            return 'LATN_homonimy'
        else:
            return 'NO'
    elif row['OC_POS']=='ROMN':
        if 'ROMN' not in row['morph']:
            return 'ROMN_homonimy'
        else:
            return 'NO' 
    elif row['morph_POS']!=row['OC_POS']:
        return 'POS_homonymy'
    elif len(row['OC'])==1:
        return 'NO'
    elif row['morph_POS']=='NOUN':
        if str(row['morph'].case) not in list(row['OC']):
            return 'Morphol_homonimy_Noun_Case'
        if str(row['morph'].number) not in list(row['OC']):
            return 'Morphol_homonimy_Noun_Number'        
        if str(row['morph'].gender) not in list(row['OC']):
            return 'Morphol_homonimy_Noun_Gender'
        if str(row['morph'].animacy) not in list(row['OC']):
            return 'Morphol_homonimy_Noun_Animacy'
        else:
            return 'NO'
    elif row['morph_POS']=='ADJF':
        if str(row['morph'].case) not in list(row['OC']):
            return 'Morphol_homonimy_ADJF_Case'
        if str(row['morph'].number) not in list(row['OC']):
            return 'Morphol_homonimy_ADJF_Number'
        if (row['morph'].number != 'plur') and (str(row['morph'].gender) not in list(row['OC'])):
                return 'Morphol_homonimy_ADJF_Gender'
        else:
            return 'NO'
    elif row['morph_POS']=='PRTF':                                 # причастия
        if str(row['morph'].case) not in list(row['OC']):
            return 'Morphol_homonimy_PRTF_Case'
        if str(row['morph'].number) not in list(row['OC']):
            return 'Morphol_homonimy_PRTF_Number'        
        if str(row['morph'].gender) not in list(row['OC']):
            return 'Morphol_homonimy_PRTF_Gender'
        if str(row['morph'].transitivity) not in list(row['OC']):   # переходность
            return 'Morphol_homonimy_PRTF_transitivity'
        if str(row['morph'].aspect) not in list(row['OC']):
            return 'Morphol_homonimy_PRTF_Aspect'
        if str(row['morph'].tense) not in list(row['OC']):
            return 'Morphol_homonimy_PRTF_Tense'
        if str(row['morph'].voice) not in list(row['OC']):
            return 'Morphol_homonimy_PRTF_Voice'                 # залог
        else:
            return 'NO'
    elif row['morph_POS']=='NPRO':                                # местоимение-существительное
        if str(row['morph'].case) not in list(row['OC']):
            return 'Morphol_homonimy_NPRO_Case'
        if str(row['morph'].number) not in list(row['OC']):
            return 'Morphol_homonimy_NPRO_Number'
#        if str(row['morph'].person) not in list(row['OC']):
#            return 'Morphol_homonimy_NPRO_person'                 # лицо      
        else:
            return 'NO'
    elif row['morph_POS']=='NUMR':                               # числительные                    
        if str(row['morph'].case) not in list(row['OC']):
            return 'Morphol_homonimy_NUMR_Case'    
        else:
            return 'NO'       
    try:
        if set(row['OC']) in row['morph']:
            return 'NO'
    except ValueError:
        return "UNKNOWN"
    return "UNKNOWN"

# %%
def check_identity(row):
    try:
        r=set(row['OC']) in row['morph']
    except ValueError:
        return 0
    return r

def check_POS_ambig(row):
    return len(set([k.tag.POS for k in morph.parse(row['tokens'])]))>1

# %% [markdown]
# Создадим колонку Differ, содержащую True, если совпадает часть речи

# %%
ambigf['Differ'] = ambigf.apply(lambda row: check_identity(row),axis=1)
# Out:
# C:\Users\Julia\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Создадим колонку POS_ambig, содержащую True в случае возможности лексико-морфологической омонимии (множественности распознавания частей речи)

# %%
ambigf['POS_ambig'] = ambigf.apply(lambda row: check_POS_ambig(row),axis=1)
# Out:
# C:\Users\Julia\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Создадим главную колонку Homonimy, содержащую теги соответствующей омонимии.

# %%
ambigf['Homonimy'] = ambigf.apply(lambda row: check_homonimy(row),axis=1)
# Out:
# C:\Users\Julia\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# UNKNOWN означает, что тег не присвоен по какой-то причине. Таких слов всего 6, помотрим вручную, что ошибок нет:

# %%
ambigf[ambigf.Homonimy == 'UNKNOWN']
# Out:
#         tokens morph_POS OC_POS morph            OC  ambig Differ  POS_ambig  \
# 13736  честнее      COMP   COMP  COMP  [COMP, Qual]   True  False      False
# 31193   кругом      ADVB   ADVB  ADVB  [ADVB, Prdx]   True  False       True
# 65073   кругом      ADVB   ADVB  ADVB  [ADVB, Prdx]   True  False       True
# 77541   Кругом      ADVB   ADVB  ADVB  [ADVB, Prdx]   True  False       True
# 82365   кругом      ADVB   ADVB  ADVB  [ADVB, Prdx]   True  False       True
# 83332   кругом      ADVB   ADVB  ADVB  [ADVB, Prdx]   True  False       True
#
#       Homonimy
# 13736  UNKNOWN
# 31193  UNKNOWN
# 65073  UNKNOWN
# 77541  UNKNOWN
# 82365  UNKNOWN
# 83332  UNKNOWN

# %%
k = ambigf['Homonimy'].value_counts()
print(k)
# Out:
# NO                               22269
# Morphol_homonimy_Noun_Case        4086
# Morphol_homonimy_ADJF_Case        1270
# POS_homonymy                      1024
# Morphol_homonimy_ADJF_Gender       294
# Morphol_homonimy_Noun_Gender       226
# Morphol_homonimy_Noun_Animacy      180
# Morphol_homonimy_NPRO_Case         108
# Morphol_homonimy_PRTF_Gender        71
# Morphol_homonimy_PRTF_Case          44
# ROMN_homonimy                       15
# Morphol_homonimy_Noun_Number        14
# Morphol_homonimy_NUMR_Case          13
# UNKNOWN                              6
# LATN_homonimy                        3
# Name: Homonimy, dtype: int64

# %%
possible_hom = ambigf.shape[0]
num_words = frame.shape[0]
no_mistakes=k[0]
mistakes = sum(k[1:-1])
print('\n Correct:', num_words-mistakes, '\n wrong:', mistakes, '\n Percent of correct:', (num_words-mistakes)/num_words )
# Out:
#  Correct: 59963
#  wrong: 7351
#  Percent of correct: 0.8907953768903942

# %%
for i in k[1:-1]:
    print(i/mistakes*100)
# Out:
# 55.58427424840158
# 17.276561012107198
# 13.930077540470684
# 3.9994558563460756
# 3.074411644674194
# 2.4486464426608627
# 1.4691878655965174
# 0.9658549857162292
# 0.5985580193170997
# 0.20405387022173854
# 0.19045027887362262
# 0.17684668752550675
# 0.08162154808869541

# %%
ambigf[ambigf.Homonimy == 'POS_homonymy']
# Out:
#            tokens morph_POS OC_POS                                    morph  \
# 33            это      PRCL   NPRO                                     PRCL
# 51            Это      PRCL   NPRO                                     PRCL
# 86            Это      PRCL   NPRO                                     PRCL
# 291       ночному      NOUN   ADJF                 NOUN,inan,neut sing,datv
# 375             и      CONJ   PRCL                                     CONJ
# 379     Маленькой      NOUN   ADJF                 NOUN,anim,femn sing,gent
# 435        осенью      NOUN   ADVB                 NOUN,inan,femn sing,ablt
# 438         зимой      ADVB   NOUN                                     ADVB
# 596          тоже      ADVB   PRCL                                     ADVB
# 606      устарела      ADJS   VERB                           ADJS femn,sing
# 637           так      CONJ   ADVB                                     CONJ
# 708         боком      ADVB   NOUN                                     ADVB
# 739      казалось      CONJ   VERB                                CONJ,Prnt
# 752         всего      ADVB   PRCL                                     ADVB
# 835      золотого      NOUN   ADJF                 NOUN,inan,masc sing,gent
# 845          этим      NPRO   ADJF                      NPRO,neut sing,ablt
# 948          прав      NOUN   ADJS                 NOUN,inan,neut plur,gent
# 969           чем      CONJ   NPRO                                     CONJ
# 991      стороной      ADVB   NOUN                                     ADVB
# 1092        любой      NOUN   ADJF            NOUN,anim,femn,Name sing,ablt
# 1143    Согласные      NOUN   ADJF                 NOUN,inan,masc plur,nomn
# 1154    согласных      NOUN   ADJF                 NOUN,inan,masc plur,gent
# 1243          всё      ADJF   PRCL                 ADJF,Apro neut,sing,nomn
# 1302     наверное      ADVB   CONJ                                     ADVB
# 1331          Нет      PRED   PRCL                                PRED,pres
# 1420       стояла      ADJS   VERB                           ADJS femn,sing
# 1464         рада      NOUN   ADJS                 NOUN,inan,femn sing,nomn
# 1465        этому      NPRO   ADJF                      NPRO,neut sing,datv
# 1552     прохожих      ADJF   NOUN                           ADJF plur,gent
# 1563   Чайковской      ADJF   NOUN                      ADJF femn,sing,gent
# ...           ...       ...    ...                                      ...
# 90626     говорят      CONJ   VERB                                CONJ,Prnt
# 90643        вещи      ADJS   NOUN                                ADJS plur
# 90649           О      PREP   INTJ                                     PREP
# 90665   маленькую      NOUN   ADJF                 NOUN,anim,femn sing,accs
# 90667         Иду      VERB   NOUN       VERB,impf,intr sing,1per,pres,indc
# 90821      Стояла      ADJS   VERB                           ADJS femn,sing
# 90931     говорят      CONJ   VERB                                CONJ,Prnt
# 90969        тоже      ADVB   PRCL                                     ADVB
# 91132    пашенных      NOUN   ADJF  NOUN,anim,GNdr,Ms-f,Fixd,Surn sing,nomn
# 91261        мимо      ADVB   PREP                                     ADVB
# 91388       стоял      ADJS   VERB                           ADJS masc,sing
# 91448        себе      NPRO   PRCL                      NPRO,Anph sing,datv
# 91478      Скупая      GRND   ADJF                      GRND,impf,tran pres
# 91510       любой      NOUN   ADJF            NOUN,anim,femn,Name sing,ablt
# 91538        пока      ADVB   CONJ                                     ADVB
# 91673        тоже      ADVB   PRCL                                     ADVB
# 91679       летом      ADVB   NOUN                                     ADVB
# 91709       летом      ADVB   NOUN                                     ADVB
# 91724        тоже      ADVB   PRCL                                     ADVB
# 91757     Полноте      NOUN   PRCL            NOUN,inan,femn,Sgtm sing,loct
# 91816   виновного      ADJF   NOUN                 ADJF,Qual masc,sing,gent
# 91829         чем      CONJ   NPRO                                     CONJ
# 91870   присяжных      ADJF   NOUN                      ADJF,Qual plur,gent
# 91916        тоже      ADVB   PRCL                                     ADVB
# 91918       новое      NOUN   ADJF                 NOUN,inan,neut sing,nomn
# 91934        тоже      ADVB   PRCL                                     ADVB
# 91969      служил      ADJS   VERB                           ADJS masc,sing
# 92014       Всего      ADVB   PRCL                                     ADVB
# 92335        тоже      ADVB   PRCL                                     ADVB
# 93362        Тоже      ADVB   PRCL                                     ADVB
#
#                                                OC  ambig Differ  POS_ambig  \
# 33                       [NPRO, neut, sing, nomn]   True  False       True
# 51                       [NPRO, neut, sing, nomn]   True  False       True
# 86                       [NPRO, neut, sing, nomn]   True  False       True
# 291                      [ADJF, masc, sing, datv]   True  False       True
# 375                                        [PRCL]   True  False       True
# 379                [ADJF, Qual, femn, sing, loct]   True  False       True
# 435                                        [ADVB]   True  False       True
# 438                [NOUN, inan, femn, sing, ablt]   True  False       True
# 596                                        [PRCL]   True  False       True
# 606    [VERB, perf, intr, femn, sing, past, indc]   True  False       True
# 637                                  [ADVB, Dmns]   True  False       True
# 708                [NOUN, inan, masc, sing, ablt]   True  False       True
# 739    [VERB, impf, intr, neut, sing, past, indc]   True  False       True
# 752                                        [PRCL]   True  False       True
# 835                      [ADJF, neut, sing, gent]   True  False       True
# 845          [ADJF, Subx, Apro, Anph, plur, datv]   True  False       True
# 948                      [ADJS, Qual, masc, sing]   True  False       True
# 969                      [NPRO, neut, sing, loct]   True  False       True
# 991                [NOUN, inan, femn, sing, ablt]   True  False       True
# 1092               [ADJF, Apro, femn, sing, loct]   True  False       True
# 1143               [ADJF, Subx, Qual, plur, nomn]   True  False       True
# 1154               [ADJF, Subx, Qual, plur, gent]   True  False       True
# 1243                                       [PRCL]   True  False       True
# 1302                                 [CONJ, Prnt]   True  False       True
# 1331                                       [PRCL]   True  False       True
# 1420   [VERB, impf, intr, femn, sing, past, indc]   True  False       True
# 1464                           [ADJS, femn, sing]   True  False       True
# 1465   [ADJF, Subx, Apro, Anph, masc, sing, datv]   True  False       True
# 1552               [NOUN, anim, masc, plur, accs]   True  False       True
# 1563   [NOUN, anim, femn, Sgtm, Surn, sing, gent]   True  False       True
# ...                                           ...    ...    ...        ...
# 90626  [VERB, impf, tran, plur, 3per, pres, indc]   True  False       True
# 90643              [NOUN, inan, femn, plur, accs]   True  False       True
# 90649                                      [INTJ]   True  False       True
# 90665              [ADJF, Qual, femn, sing, accs]   True  False       True
# 90667        [NOUN, anim, femn, Name, sing, accs]   True  False       True
# 90821  [VERB, impf, intr, femn, sing, past, indc]   True  False       True
# 90931  [VERB, impf, tran, plur, 3per, pres, indc]   True  False       True
# 90969                                      [PRCL]   True  False       True
# 91132                    [ADJF, Qual, plur, gent]   True  False       True
# 91261                                      [PREP]   True  False       True
# 91388  [VERB, impf, intr, masc, sing, past, indc]   True  False       True
# 91448                                      [PRCL]   True  False       True
# 91478              [ADJF, Qual, femn, sing, nomn]   True  False       True
# 91510              [ADJF, Apro, femn, sing, ablt]   True  False       True
# 91538                                      [CONJ]   True  False       True
# 91673                                      [PRCL]   True  False       True
# 91679        [NOUN, inan, neut, Sgtm, sing, ablt]   True  False       True
# 91709        [NOUN, inan, neut, Sgtm, sing, ablt]   True  False       True
# 91724                                      [PRCL]   True  False       True
# 91757                                      [PRCL]   True  False       True
# 91816              [NOUN, anim, masc, sing, accs]   True  False       True
# 91829                    [NPRO, neut, sing, loct]   True  False       True
# 91870              [NOUN, anim, masc, plur, gent]   True  False       True
# 91916                                      [PRCL]   True  False       True
# 91918              [ADJF, Qual, neut, sing, accs]   True  False       True
# 91934                                      [PRCL]   True  False       True
# 91969  [VERB, impf, tran, masc, sing, past, indc]   True  False       True
# 92014                                      [PRCL]   True  False       True
# 92335                                      [PRCL]   True  False       True
# 93362                                      [PRCL]   True  False       True
#
#            Homonimy
# 33     POS_homonymy
# 51     POS_homonymy
# 86     POS_homonymy
# 291    POS_homonymy
# 375    POS_homonymy
# 379    POS_homonymy
# 435    POS_homonymy
# 438    POS_homonymy
# 596    POS_homonymy
# 606    POS_homonymy
# 637    POS_homonymy
# 708    POS_homonymy
# 739    POS_homonymy
# 752    POS_homonymy
# 835    POS_homonymy
# 845    POS_homonymy
# 948    POS_homonymy
# 969    POS_homonymy
# 991    POS_homonymy
# 1092   POS_homonymy
# 1143   POS_homonymy
# 1154   POS_homonymy
# 1243   POS_homonymy
# 1302   POS_homonymy
# 1331   POS_homonymy
# 1420   POS_homonymy
# 1464   POS_homonymy
# 1465   POS_homonymy
# 1552   POS_homonymy
# 1563   POS_homonymy
# ...             ...
# 90626  POS_homonymy
# 90643  POS_homonymy
# 90649  POS_homonymy
# 90665  POS_homonymy
# 90667  POS_homonymy
# 90821  POS_homonymy
# 90931  POS_homonymy
# 90969  POS_homonymy
# 91132  POS_homonymy
# 91261  POS_homonymy
# 91388  POS_homonymy
# 91448  POS_homonymy
# 91478  POS_homonymy
# 91510  POS_homonymy
# 91538  POS_homonymy
# 91673  POS_homonymy
# 91679  POS_homonymy
# 91709  POS_homonymy
# 91724  POS_homonymy
# 91757  POS_homonymy
# 91816  POS_homonymy
# 91829  POS_homonymy
# 91870  POS_homonymy
# 91916  POS_homonymy
# 91918  POS_homonymy
# 91934  POS_homonymy
# 91969  POS_homonymy
# 92014  POS_homonymy
# 92335  POS_homonymy
# 93362  POS_homonymy
#
# [1024 rows x 9 columns]

# %%
toc = ambigf[ambigf.Homonimy!='NO']['tokens'].value_counts()
print(toc[1:10])
# Out:
# России     52
# тоже       45
# этом       44
# США        42
# человек    32
# мира       29
# Ссылки     26
# века       25
# этой       25
# Name: tokens, dtype: int64

# %%
morph.parse('арене')
# Out:
# [Parse(word='арене', tag=OpencorporaTag('NOUN,anim,masc,Name sing,loct'), normal_form='арен', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'арене', 26, 5),)),
#  Parse(word='арене', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='арена', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'арене', 55, 2),)),
#  Parse(word='арене', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='арена', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'арене', 55, 6),))]

# %%
ambigf[28:38]
# Out:
#              tokens morph_POS OC_POS                               morph  \
# 55                в      PREP   PREP                                PREP
# 57              тут      ADVB   ADVB                           ADVB,Dmns
# 58               же      PRCL   PRCL                                PRCL
# 59      появившихся      PRTF   PRTF  PRTF,perf,intr,past,actv plur,gent
# 60        рекламных      ADJF   ADJF                 ADJF,Qual plur,gent
# 63  отсутствовавших      PRTF   PRTF  PRTF,impf,intr,past,actv plur,gent
# 64               на      PREP   PREP                                PREP
# 66         Культуре      NOUN   NOUN            NOUN,inan,femn sing,datv
# 71                с      PREP   PREP                                PREP
# 72            одной      ADJF   ADJF            ADJF,Apro femn,sing,gent
#
#                                             OC  ambig Differ  POS_ambig  \
# 55                                      [PREP]   True   True       True
# 57                                [ADVB, Dmns]   True   True       True
# 58                                      [PRCL]   True   True       True
# 59  [PRTF, perf, intr, past, actv, plur, gent]   True   True      False
# 60                    [ADJF, Qual, plur, gent]   True   True      False
# 63  [PRTF, impf, intr, past, actv, plur, gent]   True   True      False
# 64                                      [PREP]   True   True       True
# 66              [NOUN, inan, femn, sing, loct]   True  False      False
# 71                                      [PREP]   True   True       True
# 72        [ADJF, Apro, Anum, femn, sing, gent]   True  False      False
#
#                         Homonimy
# 55                            NO
# 57                            NO
# 58                            NO
# 59  Morphol_homonimy_PRTF_Gender
# 60                            NO
# 63  Morphol_homonimy_PRTF_Gender
# 64                            NO
# 66    Morphol_homonimy_Noun_Case
# 71                            NO
# 72                            NO
